# %%
import requests

# %%
import sqlite3

# %% [markdown]
# ## Getting Language

# %%
r = requests.post('http://127.0.0.1:13522/snippets', json={"search_word":"водител в"})
print(r.status_code)
print(r.text)

# %%
r.text[0:120]

# %%
r = requests.post('http://127.0.0.1:13522/search', json={"search_word":"водител в"})
print(r.status_code)
print(r.text)
serach_res = r.text
# Out:
# 200
# ...

# %%
r = requests.post('http://127.0.0.1:13522/snippets', data=serach_res)

# %%
r = requests.post('http://127.0.0.1:13522/rev_ind', json={"stemmed_text":stemmed_text})
print(r.status_code)
print(r.text)
# Out:
# 200
# {"idxs": [2, 6, 4, 8, 6, 6, 6, 6, 6, 5, 3], "tstemmed_textext": ["it", "import", "veri", "pythonli", "python", "python", "python", "python", "poorli", "least", "onc"]}

# %%
def get_snippet():
# Out:
#   File "<ipython-input-57-5f2358ea2779>", line 1
#     def get_snippet():
#                       ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ## Processing Text

# %%
#Stemming
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk
nltk.download('punkt') 
ps = PorterStemmer()
new_text = "It is important to by very pythonly while you are pythoning with python. All pythoners have pythoned poorly at least once."

words = word_tokenize(new_text)
tokenized_words = []
for w in words:
    tokenized_words.append(ps.stem(w))

#Excluding Stop-words
from nltk.corpus import stopwords
filtered_words = [word.lower() for word in tokenized_words if word not in stopwords.words('english') and word.isalpha()]
print(filtered_words)
# Out:
# [nltk_data] Downloading package punkt to /home/math/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['it', 'import', 'veri', 'pythonli', 'python', 'python', 'python', 'python', 'poorli', 'least', 'onc']

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/math/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True
