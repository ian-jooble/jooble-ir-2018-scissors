# %%
import json
import gzip
import os

import requests
import pandas as pd

import config

# %%
indexer_url = config.indexer_url
text_processing_url = config.text_processing_url
ranking_url = config.ranking_url
snippets_url = config.snippets_url
res_page_form_url = config.res_page_form_url

query = "водитель"

# %%
print("Accessing indexer")
r = requests.post(indexer_url)
print(r.status_code)
print(r.text)

print("\nNormalizing document")
#  normalize the document
r = requests.post(text_processing_url + "normalize_document",
                  json={"id": 7, "title": "Садоводство",
                        "text": "Саженцы декоративных и плодовых культур. "
                                "Могилев. Гарантия."})
print(r.status_code)
print(json.loads(r.text))
document = json.loads(r.text, encoding="utf-8")
print("\nAdding document to index")

#  add the document to index
r = requests.post(indexer_url + "indexer", json=document)
print(r.status_code)
print(r.text)

print("\nNormalizing search query")
#  normalize the search query
r = requests.post(text_processing_url + "normalize_query",
                  json=query)
print(r.status_code)
#print(str(r.text))
search_query = r.text

print("\nSearching in index")
# search in index
r = requests.post(indexer_url + "search",
                  json=search_query)
print(r.status_code)
#print(r.text)
#search_results = type(json.loads(r.text, encoding="utf-8"))

search_results = json.loads(r.text, encoding="utf-8")


print("\nBM-25 Ranking")
# getting search results with snippets
h_query = r.text

r = requests.post(ranking_url + config.RANK_PATH,
                  json=search_results)
print(r.status_code)
print(r.text)

print("\nGetting snippet-list")
# getting search results with snippets
h_query = r.text

r = requests.post(snippets_url + "snippets",
                  json=search_results)
print(r.status_code)
#print(r.text)
srch_results = r.text

print("\nSERP results")
# getting search results with snippets
h_query = r.text

r = requests.post(res_page_form_url + "result_page",
                  json=h_query)
print(r.status_code)
print(r.text)
# Out:
# Accessing indexer
# 200
# Main page of indexer
#
# Normalizing document
# 200
# {'id': 7, 'title': 'Садоводство', 'text': 'Саженцы декоративных и плодовых культур. Могилев. Гарантия.', 'text_normalized': 'саженц декоративн и плодов культур могил гарант', 'title_normalized': 'садоводств'}
#
# Adding document to index
# 200
# document already exist in index.
#
# Normalizing search query
# 200
#
# Searching in index
# 200
#
# BM-25 Ranking
# 200
# {'documents': [['хвойн', 'и', 'листвен', 'растен', 'в', 'брест', 'из', 'питомник', 'гарант', 'предлага', 'больш', 'ассортимент', 'растен', 'бол', 'наименован', 'собствен', 'производств', 'а', 'такж', 'новинк', 'эт', 'сезон', 'от', 'известн', 'производител', 'европ', 'доставк', 'в', 'люб', 'точк', 'рб', 'хвойн', 'и', 'декоративн', 'растен', 'гортенз', 'ту', 'можжевельник', 'ел', 'пихт', 'вереск', 'и', 'мног', 'друг', 'лиа', 'клематис', 'калистег', 'жимол', 'японск', 'саженц', 'плодов', 'культур', 'черешн', 'вишн', 'яблон', 'груш', 'слив', 'абрикос', 'персик', 'и', 'саженц', 'роз', 'миниатюрн', 'плетист', 'штамбов', 'луковиц', 'цвет', 'гиацинт', 'крокус', 'лил', 'тюльпа', 'нарцисс', 'амариллис', 'рябчик', 'бол', 'наименован', 'саженц', 'ягодн', 'культур', 'смородин', 'крыжовник', 'голубик', 'жимол', 'малин', 'киз', 'и', 'комнатн', 'растен', 'лимон', 'лавр', 'благородн', 'мандарин', 'инжир', 'мирт', 'опт', 'и', 'розниц', 'звон', 'сайт'], ['учител', 'физическ', 'культур', 'и', 'здоров', 'ставк', 'высш', 'педагогическ', 'образован'], ['предлага', 'больш', 'ассортимент', 'растен', 'собствен', 'производств', 'а', 'такж', 'новинк', 'эт', 'сезон', 'от', 'известн', 'производител', 'европ', 'доставк', 'в', 'люб', 'точк', 'рб', 'бол', 'наименован', 'опт', 'и', 'сайт', 'лиа', 'клематис', 'калистег', 'жимол', 'японск', 'саженц', 'роз', 'миниатюрн', 'плетист', 'штамбов', 'саженц', 'плодов', 'культур', 'яблон', 'груш', 'слив', 'черешн', 'вишн', 'абрикос', 'персик', 'и', 'луковиц', 'цвет', 'лил', 'гиацинт', 'крокус', 'тюльпа', 'нарцисс', 'амариллис', 'рябчик', 'бол', 'наименован', 'хвойн', 'и', 'декоративн', 'растен', 'ту', 'гортенз', 'можжевельник', 'ел', 'пихт', 'вереск', 'и', 'мног', 'друг', 'комнатн', 'растен', 'лимон', 'мандарин', 'инжир', 'лавр', 'благородн', 'мирт', 'саженц', 'ягодн', 'культур', 'смородин', 'крыжовник', 'голубик', 'жимол', 'малин', 'киз', 'и'], ['на', 'предприят', 'в', 'росс', 'треб', 'работник', 'грузчик', 'разнорабоч', 'работник', 'в', 'кофейн', 'официант', 'уборщиц', 'кассир', 'мойщиц', 'посуд', 'на', 'рыбзавод', 'проживан', 'бесплатн', 'униформ', 'выда', 'вахт', 'ил', 'месяц', 'зп', 'за', 'смен']], 'terms': [{'term': 'водител', 'inverted_index': [{'id': -4626008834507944781, 'count': 1, 'count_title': 0, 'length': 7, 'pos': [240], 'pos_raw': [457]}, {'id': -4724203981370219140, 'count': 2, 'count_title': 1, 'length': 7, 'pos': [4, 30], 'pos_raw': [4, 65]}, {'id': -4724203981370219140, 'count': 2, 'count_title': 1, 'length': 7, 'pos': [4, 30], 'pos_raw': [4, 65]}, {'id': 3214916160176031728, 'count': 1, 'count_title': 1, 'length': 7, 'pos': [75], 'pos_raw': []}, {'id': 7106787887579010943, 'count': 1, 'count_title': 1, 'length': 7, 'pos': [75], 'pos_raw': []}, {'id': -6143225872344418851, 'count': 1, 'count_title': 1, 'length': 7, 'pos': [9, 279], 'pos_raw': [11, 422]}, {'id': 722046475987764177, 'count': 2, 'count_title': 1, 'length': 7, 'pos': [5, 56, 119], 'pos_raw': [10, 70, 146]}, {'id': 722046475987764177, 'count': 2, 'count_title': 1, 'length': 7, 'pos': [5, 56, 119], 'pos_raw': [10, 70, 146]}, {'id': -5568249027611832128, 'count': 1, 'count_title': 1, 'length': 7, 'pos': [75], 'pos_raw': []}, {'id': 8094358512615634990, 'count': 1, 'count_title': 1, 'length': 7, 'pos': [5], 'pos_raw': [10]}, {'id': -6059014742122923005, 'count': 2, 'count_title': 1, 'length': 7, 'pos': [4, 30], 'pos_raw': [4, 65]}, {'id': -6059014742122923005, 'count': 2, 'count_title': 1, 'length': 7, 'pos': [4, 30], 'pos_raw': [4, 65]}, {'id': -2648428394124377337, 'count': 1, 'count_title': 1, 'length': 7, 'pos': [9], 'pos_raw': [11]}, {'id': -1536162289734899176, 'count': 1, 'count_title': 0, 'length': 7, 'pos': [76], 'pos_raw': [101]}, {'id': 7413656967882446410, 'count': 1, 'count_title': 1, 'length': 7, 'pos': [5], 'pos_raw': [10]}, {'id': -3644320679646299, 'count': 1, 'count_title': 0, 'length': 7, 'pos': [27], 'pos_raw': [36]}, {'id': -7233390228513131590, 'count': 2, 'count_title': 1, 'length': 7, 'pos': [49, 92, 193], 'pos_raw': [ ...
#
# Getting snippet-list
# 500
#
# SERP results
# 500
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <title>500 Internal Server Error</title>
# <h1>Internal Server Error</h1>
# <p>The server encountered an internal error and was unable to complete your request.  Either the server is overloaded or there is an error in the application.</p>
